# %%
# Dependencies
import pandas as pd
import numpy as np

# %%
# Name of the CSV file
file = '2012-18_teamBoxScore.csv'

# %%
# The correct encoding must be used to read the CSV in pandas
df = pd.read_csv(file, encoding="ISO-8859-1")

# %%
# Preview of the DataFrame
# Note that FIELD8 is likely a meaningless column
df.head()
# Out:
#        gmDate gmTime  seasTyp    offLNm1 offFNm1    offLNm2  offFNm2  \
# 0  2012-10-30  19:00  Regular   Brothers    Tony      Smith  Michael
# 1  2012-10-30  19:00  Regular   Brothers    Tony      Smith  Michael
# 2  2012-10-30  20:00  Regular  McCutchen   Monty     Wright     Sean
# 3  2012-10-30  20:00  Regular  McCutchen   Monty     Wright     Sean
# 4  2012-10-30  22:30  Regular     Foster   Scott  Zielinski     Gary
#
#       offLNm3   offFNm3 teamAbbr   ...    opptFIC40  opptOrtg  opptDrtg  \
# 0     Workman  Haywoode      WAS   ...      61.6667  105.6882   94.4447
# 1     Workman  Haywoode      CLE   ...      56.0417   94.4447  105.6882
# 2  Fitzgerald      Kane      BOS   ...      80.8333  126.3381  112.6515
# 3  Fitzgerald      Kane      MIA   ...      62.7083  112.6515  126.3381
# 4       Dalen      Eric      DAL   ...      58.6458   99.3678  108.1034
#
#   opptEDiff  opptPlay%   opptAR  opptAST/TO  opptSTL/TO     poss     pace
# ...

# %%
df.shape
# Out:
# (14758, 123)

# %%
df.columns
# Out:
# Index(['gmDate', 'gmTime', 'seasTyp', 'offLNm1', 'offFNm1', 'offLNm2',
#        'offFNm2', 'offLNm3', 'offFNm3', 'teamAbbr',
#        ...
#        'opptFIC40', 'opptOrtg', 'opptDrtg', 'opptEDiff', 'opptPlay%', 'opptAR',
#        'opptAST/TO', 'opptSTL/TO', 'poss', 'pace'],
#       dtype='object', length=123)

# %%
reduced_df = df.loc[:, ["teamRslt","teamPTS", "teamAST", "teamTO", "teamSTL", "teamBLK", "teamPF", "teamFGA", "teamFGM", 
                        "team2PM", "team3PM","opptPTS", "opptAST", "opptTO", "opptSTL", "opptBLK", "opptPF", "opptFGA", 
                        "opptFGM", "oppt2PM", "oppt3PM"]]
reduced_df.head()
# Out:
#   teamRslt  teamPTS  teamAST  teamTO  teamSTL  teamBLK  teamPF  teamFGA  \
# 0     Loss       84       26      13       11       10      19       90
# 1      Win       94       22      21        7        5      21       79
# 2     Loss      107       24      16        4        2      23       75
# 3      Win      120       25       8        8        5      20       79
# 4      Win       99       22      12        9        5      25       85
#
#    teamFGM  team2PM   ...     opptPTS  opptAST  opptTO  opptSTL  opptBLK  \
# 0       32       24   ...          94       22      21        7        5
# 1       36       29   ...          84       26      13       11       10
# 2       39       33   ...         120       25       8        8        5
# 3       43       35   ...         107       24      16        4        2
# 4       40       35   ...          91       24      14        6        5
#
#    opptPF  opptFGA  opptFGM  oppt2PM  oppt3PM
# 0      21       79       36       29        7
# ...

# %%
advance_stats_df = df.loc[:, ['teamRslt', 'team3PA', 'team3P%', 'teamFTA', 'teamTREB%', 
                              'teamASST%', 'teamEFG%', 'teamAST/TO', 'teamTO%']]

stats_df = df.loc[:, ["teamAST", "teamTO", "teamSTL", "teamBLK", "teamPF", "teamFGA",
                        "team2PM", "team3PM","opptAST", "opptTO", "opptSTL", "opptBLK", "opptPF", "opptFGA", 
                        "oppt2PM", "oppt3PM",'teamRslt', 'team3PA', 'team3P%', 'teamFTA', 'teamTREB%', 
                              'teamASST%', 'teamEFG%', 'teamAST/TO', 'teamTO%']]

# %%
advance_stats_df.to_csv('nba_advance_stats', encoding = 'utf-8', index = False)

# %%
reduced_df.to_csv("nba_test_stats", encoding = 'utf-8', index = False)

# %%
stats_df.to_csv('full_stats', encoding = 'utf-8', index = False)
